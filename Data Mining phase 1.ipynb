# %% [markdown]
# # Data Mining project Phase 1

# %% [markdown]
# Faridreza Momtaz Zandi 9812762601
# Alireza Noorbakhsh 9812762496

# %% [markdown]
# Main focus in this phase was to understand datasets and how to work with them. We start by finding out our data types in the datasets and finally  work on the numerical attrebutes to have basic knowledge of our atterbutes such as min, max, mean, range etc.
# We proceed to check our datasets one by one and get a full grasp on them.

# %% [markdown]
# #  INOUT Dataset

# %% [markdown]
# Unfortunatly there is no numerical attribute in this dataset and all of them are either Nominal, Ordinal or Binary and even the attributes that seems to be numeric are representing date or some sort of ID and there is no point or goal in workong on them and finding out their min, max, median etc.

# %% [markdown]
# # INOUTLINE Dataset

# %% [markdown]
# Unlike our last dataset in this one we have a few numerical attributes that we can work on and get a sense of how is it to work on datasets! we begin by choosing these attributes and finally code!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('E:\ce\data mining\DataSets\INOUTLINE.csv' , low_memory = False)
df = df[['ACCUMULATEDEPRECIATION' , 'BOOKVALUE' , 'PRIMALVALUE' ,'DEPRECATION_PERIOD']]
ogdf = df
median_df = df.median()
mode_df = df.mode()
df = df.describe()
df = df.transpose()
df['range'] = df['max'] - df['min']
df['Min acceptable value'] = df['min'] - ((df['max'] - df['min']) * 1.5)
df['Max acceptable value'] = df['max'] + ((df['max'] - df['min']) * 1.5)
df['median'] = median_df
df['mode'] = mode_df.head(1).transpose()
df = df.drop(columns = ['std' ,'count'])
df = df[['range' , 'min' , 'max' , 'mean' ,'mode' , 'median' , 'Min acceptable value' , 'Max acceptable value']]
df
# Out:
#                                range  min           max          mean  mode  \
# ACCUMULATEDEPRECIATION  2.356000e+08  0.0  2.356000e+08  4.098806e+05   0.0
# BOOKVALUE               6.564481e+08  0.0  6.564481e+08  6.981809e+05   1.0
# PRIMALVALUE             1.954043e+10  0.0  1.954043e+10  1.458704e+07   1.0
# DEPRECATION_PERIOD      1.000197e+06  2.0  1.000199e+06  2.500512e+05   2.0
#
#                            median  Min acceptable value  Max acceptable value
# ACCUMULATEDEPRECIATION        0.0         -3.534000e+08          5.890000e+08
# BOOKVALUE                     1.0         -9.846722e+08          1.641120e+09
# PRIMALVALUE             1880000.0         -2.931064e+10          4.885108e+10
# DEPRECATION_PERIOD            2.0         -1.500294e+06          2.500494e+06

# %% [markdown]
# Now that we have the table we can draw our box plots:

# %%
ogdf['ACCUMULATEDEPRECIATION'].plot(kind = 'box' , title = 'ACCUMULATEDEPRECIATION' , figsize = (10,8))
plt.show()
ogdf['BOOKVALUE'].plot(kind = 'box' , title = 'BOOKVALUE' , figsize = (10,8))
plt.show()
ogdf['PRIMALVALUE'].plot(kind = 'box' , title = 'PRIMALVALUE' , figsize = (10,8))
plt.show()
ogdf['DEPRECATION_PERIOD'].plot(kind = 'box' , title = 'DEPRECATION_PERIOD' , figsize = (10,8))
plt.show()

# %% [markdown]
# # PRODUCTINSTANCE Dataset

# %% [markdown]
# Here is our biggest dataset but is also as messy and although we have lots and lots of attributes most of them doesn't have concistancy in their data types but we managed to find some that are consistent and also numerical! here they are:

# %%
import pandas as pd
df = pd.read_csv('E:\ce\data mining\DataSets\PRODUCTINSTANCE.csv' , encoding='cp1252' , low_memory=False)
df = df[['PRICE9' , 'SALVAGEVALUE' , 'PI_VALUEAFTERCOEFFICIENTINC' , 'COEFFICIENTVALUE' , 'ANTIQUITYCOEFFICIENT'
       , 'PRESENTVALUE' , 'BOOKVALUE' , 'AREA_TOTAL']]
ogdf = df
median_df = df.median()
mode_df = df.mode()
df = df.describe()
df = df.transpose()
df['range'] = df['max'] - df['min']
df['Min acceptable value'] = df['min'] - ((df['max'] - df['min']) * 1.5)
df['Max acceptable value'] = df['max'] + ((df['max'] - df['min']) * 1.5)
df['median'] = median_df
df['mode'] = mode_df.head(1).transpose()
df = df.drop(columns = ['std' ,'count'])
df = df[['range' , 'min' , 'max' , 'mean' ,'mode' , 'median' , 'Min acceptable value' , 'Max acceptable value']]
df
# Out:
#                                     range       min           max  \
# PRICE9                       4.696381e+08       0.0  4.696381e+08
# SALVAGEVALUE                 4.438800e+08       0.0  4.438800e+08
# PI_VALUEAFTERCOEFFICIENTINC  5.600000e+10       0.0  5.600000e+10
# COEFFICIENTVALUE             5.000000e+00       0.0  5.000000e+00
# ANTIQUITYCOEFFICIENT         5.000000e+00       0.0  5.000000e+00
# PRESENTVALUE                 7.854600e+07       0.0  7.854600e+07
# BOOKVALUE                    1.620218e+10       0.0  1.620218e+10
# AREA_TOTAL                   2.123433e+09 -104592.0  2.123328e+09
#
#                                      mean      mode     median  \
# PRICE9                       1.431538e+08    1304.0     1304.0
# SALVAGEVALUE                 1.377224e+07       0.0    77625.0
# PI_VALUEAFTERCOEFFICIENTINC  9.521633e+07       0.0  1225000.0
# COEFFICIENTVALUE             1.212077e+00       1.0        1.0
# ...

# %% [markdown]
# Now that we have the table we can draw our box plots:

# %%
ogdf['PRICE9'].plot(kind = 'box' , title = 'PRICE9' , figsize = (10,8))
plt.show()
ogdf['SALVAGEVALUE'].plot(kind = 'box' , title = 'SALVAGEVALUE' , figsize = (10,8))
plt.show()
ogdf['PI_VALUEAFTERCOEFFICIENTINC'].plot(kind = 'box' , title = 'PI_VALUEAFTERCOEFFICIENTINC' , figsize = (10,8))
plt.show()
ogdf['COEFFICIENTVALUE'].plot(kind = 'box' , title = 'COEFFICIENTVALUE' , figsize = (10,8))
plt.show()
ogdf['ANTIQUITYCOEFFICIENT'].plot(kind = 'box' , title = 'ANTIQUITYCOEFFICIENT' , figsize = (10,8))
plt.show()
ogdf['PRESENTVALUE'].plot(kind = 'box' , title = 'PRESENTVALUE' , figsize = (10,8))
plt.show()
ogdf['BOOKVALUE'].plot(kind = 'box' , title = 'BOOKVALUE' , figsize = (10,8))
plt.show()
ogdf['AREA_TOTAL'].plot(kind = 'box' , title = 'AREA_TOTAL' , figsize = (10,8))
plt.show()

# %% [markdown]
# # TRANSFER_ITEM and TRANSFER_ITEM_D Datasets

# %% [markdown]
# Both these Datasets are like the first one and doesn't have any numeric attributes that we can work on.

# %% [markdown]
# # Suggestions for analysing data

# %% [markdown]
# After understanding what our data is we can now get a full image of what we can do with it, other than predicitng prices we'll know what products might be low in storage so we can predict the date of our products running out.
# Our newly gained knowledge lets us to find out what products are more profitible because we have the price and the profit we'll get from them and also we have the rate these items are sold in so we just need to put them in a formula and find what products are our favourites!
# We got lots of information about when and how our products are stored so if we wish to move our products or make our storage more efficient.
